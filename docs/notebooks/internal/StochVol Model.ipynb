# %% [markdown]
# ## Simple Stochastic Volatility Model
#
# $$
# dX_t = \sqrt{Z_t} dW^x_t \\
# dZ_t = (\theta + \kappa Z_t) dt + \sigma_z \sqrt{Z_t} dW_t^z
# $$

# %%
import jax
import jax.numpy as jnp
import jax.scipy as jsp
import jax.random as random
from jax import lax
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# plotting
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import pfjax as pf
import pfjax.sde as sde

from functools import partial

import pfjax as pf
from pfjax import particle_resamplers as resampler

import time
from tqdm import tqdm

import warnings
warnings.filterwarnings("ignore")

# %%
from pfjax.models.base_model import BaseModel
from pfjax import sde
import pfjax.mcmc as mcmc

# %%
def euler_sim_nojump(key, x, dt, drift_diff, theta):
    """
    Simulate SDE with dense diffusion using Euler-Maruyama discretization.
    Args:
        key: PRNG key.
        x: Initial value of the SDE.  A vector of size `n_dims`.
        dt: Interobservation time.
        drift: Drift function having signature `drift(x, theta)` and returning a vector of size `n_dims`.
        diff: Diffusion function having signature `diff(x, theta)` and returning a vector of size `n_dims`.
        theta: Parameter value.
    Returns:
        Simulated SDE values. A vector of size `n_dims`.
    """
    _, diff_subkey, jump_subkey = random.split(key, 3)
    diff_process = drift_diff(diff_subkey, x, theta, dt)
#     jump_process = jump(jump_subkey, x, theta, dt)
    return diff_process #jnp.append(diff_process + jump_process, jump_process)

class SDEModel(object):
    def __init__(self, dt, n_res):
        self._dt = dt
        self._n_res = n_res
        
        def euler_sim(self, key, x, dt, theta):
            return euler_sim_nojump(key, x, dt, self.drift_diff, theta)
        
        setattr(self.__class__, 'euler_sim', euler_sim)
    
    def state_sample(self, key, x_prev, theta):
        def fun(carry, t):
            key, subkey = random.split(carry["key"])
            x = self.euler_sim(
                key=subkey, x=carry["x"],
                dt=self._dt/self._n_res, theta=theta
            )
            res = {"x": x, "key": key}
            return res, x
        init = {"x": x_prev[-1], "key": key}
        last, full = lax.scan(fun, init, jnp.arange(self._n_res))
        return full
    
    def is_valid_state(self, x, theta):
        return not jnp.sum(x < 0) > 0
    
    def meas_lpdf(self, y_curr, x_curr, theta):
        return 1.0

# %%
class NoJumpDiff(SDEModel):
    
    def __init__(self, dt, n_res, bootstrap=False):
        super().__init__(dt, n_res)
        self._n_state = (self._n_res, 2)
    
    def _unpack(self, theta):
        return theta[0], theta[1], theta[2], theta[3]
    
    def drift(self, x, theta):
        _theta, kappa, sigma_z, mu = self._unpack(theta)
        mu = jnp.array([_theta + kappa*x[0], mu])
        return mu
    
    def diff(self, x, theta):
        _theta, kappa, sigma_z, mu = self._unpack(theta)
        Sigma = jnp.array([[x[0]*(sigma_z**2), 0],
                           [0, x[0]]])
        return Sigma
    
    def drift_diff(self, key, x, theta, dt):
        mu = self.drift(x, theta)
        Sigma = self.diff(x, theta)
        diff_process = jax.random.multivariate_normal(key, mean = x+mu*dt, cov=Sigma*dt)
        return diff_process
        
    def meas_sample(self, key, x_curr, theta):
        return x_curr[-1][1]
    
    def state_lpdf(self, x_curr, x_prev, theta):
        r"""
        Sample from Euler transition density: `p(x_curr | x_prev, theta)`
        """
        x0 = jnp.concatenate([x_prev[-1][None], x_curr[:-1]])
        x1 = x_curr
        
        def euler_lpdf_jump(x_curr, x_prev, dt, drift, diff, theta):
            return jsp.stats.norm.logpdf(
                x=x_curr[1],
                loc=x_prev[1] + drift(x_prev, theta)[1]*dt,
                scale=jnp.sqrt(diff(x_prev, theta)[1,1]*dt)
            ) 
        
        lp = jax.vmap(lambda xp, xc:
                      euler_lpdf_jump(
                          x_curr=xc, x_prev=xp,
                          dt=self._dt/self._n_res,
                          drift=self.drift,
                          diff=self.diff,
                          theta=theta))(x0, x1)
        return jnp.sum(lp)
    
    def _state_lpdf_for(self, x_curr, x_prev, theta):
        dt_res = self._dt/self._n_res
        x0 = jnp.append(jnp.expand_dims(
            x_prev[self._n_res-1], axis=0), x_curr[:self._n_res-1], axis=0)
        x1 = x_curr
        lp = jnp.array(0.0)
        
        for t in range(self._n_res):
            lp = lp + jnp.sum(jsp.stats.norm.logpdf(
                x=x1[t][1],
                loc=x0[t][1] + self.drift(x0[t], theta)[1]*dt_res,
                scale=jnp.sqrt(self.diff(x0[t], theta)[1,1]*dt_res)
            ))
        return lp
    
    def _bridge_param(self, x, y_curr, theta, n):
        _theta, kappa, sigma_z, mu = self._unpack(theta)
        k = self._n_res - n
        dt_res = self._dt/self._n_res

        mu_z = x[0] + (_theta+kappa*x[0])*dt_res 
        sig2_z = x[0]*(sigma_z**2)*dt_res

        mu_x = x[1] + (y_curr - x[1])/k 
        sig2_x = (k - 1)/k*x[0]*dt_res

        return mu_z, sig2_z, mu_x, sig2_x
    
    def pf_step(self, key, x_prev, y_curr, theta):
        key, jump_subkey, z_subkey, x_subkey = random.split(key, 4)
        def scan_fun(carry, t):
            key = carry["key"]
            x = carry["x"]

            mu_z, sig2_z, mu_x, sig2_x = self._bridge_param(x, y_curr, theta, t)
            key, z_subkey, x_subkey = random.split(key,3)

            x_prop = jnp.array([jnp.abs(mu_z + jnp.sqrt(sig2_z) * random.normal(z_subkey))+1e-10,
                                jnp.where(t < self._n_res-1, 
                                          mu_x + jnp.sqrt(sig2_x) * random.normal(x_subkey),
                                          y_curr)])

            lp_prop = jnp.where(t < self._n_res-1,
                                jsp.stats.norm.logpdf(x=x_prop[1], loc=mu_x, scale=jnp.sqrt(sig2_x)),
                                0.0)

            res_carry = {
                "x": x_prop,
                "key": key,
                "lp": carry["lp"] + lp_prop
            }
            res_stack = {"x": x_prop, "lp": lp_prop}
            return res_carry, res_stack

        scan_init = {
            "x": x_prev[self._n_res-1],
            "key": key,
            "lp": jnp.array(0.)
        }
        
        ns = jnp.arange(self._n_res)

        last, full = lax.scan(scan_fun, scan_init, (ns))
        x_prop = full["x"]
        logw_trans = self.state_lpdf(
            x_curr=x_prop,
            x_prev=x_prev, 
            theta=theta
        )

        logw = logw_trans - last["lp"]
        return x_prop, logw
    
    def _pf_step_for(self, key, x_prev, y_curr, theta):
        dt_res = self._dt/self._n_res
        x_curr = []
        x_state = x_prev[self._n_res-1]
        lp = jnp.array(0.0)
        
        key, jump_subkey, z_subkey, x_subkey = random.split(key, 4)
        
        for t in range(self._n_res):
            key, z_subkey, x_subkey = random.split(key,3)
            mu_z, sig2_z, mu_x, sig2_x = self._bridge_param(x_state, y_curr, theta, t)
            
            x_state = jnp.array([jnp.abs(mu_z + jnp.sqrt(sig2_z) * random.normal(z_subkey))+1e-10,
                                 jnp.where(t<self._n_res-1, 
                                           mu_x + jnp.sqrt(sig2_x) * random.normal(x_subkey),
                                           y_curr)])

            lp_prop = jnp.where(t<self._n_res-1,
                           jsp.stats.norm.logpdf(x=x_state[1], loc=mu_x, scale=jnp.sqrt(sig2_x)),
                           0.0)
            
            x_curr.append(x_state)
            lp = lp + lp_prop
        
        x_prop = jnp.array(x_curr)
        
        logw_trans = self._state_lpdf_for(
            x_curr=x_prop,
            x_prev=x_prev, 
            theta=theta
        )
        
        logw = logw_trans - lp
        return x_prop, logw
    
    def pf_init(self, key, y_init, theta):
        key, subkey = random.split(key)
        x_init = y_init + 5*random.normal(
            subkey
        )
        z_init = random.truncated_normal(
            subkey,
            lower=0.5,
            upper=10)
        logw = jnp.sum(jsp.stats.norm.logcdf(y_init))
        return \
            jnp.append(jnp.zeros((self._n_res-1,) + (self._n_state[1], )),
                       jnp.expand_dims(jnp.array([z_init, x_init]), axis = 0), axis=0), \
            logw

# %%
key = random.PRNGKey(0)

_dt = 1
_n_res = 5
n_obs = 500

# parameters: 
_theta = 0.02
kappa = -0.03
sigma_z = 0.12
mu = 0.008

theta = jnp.array([_theta, kappa, sigma_z, mu])
x_init = jnp.block([[jnp.zeros((_n_res-1, 2))],
                    [jnp.array([2.0, 30.0])]])

volmodel = NoJumpDiff(_dt, _n_res)

# %%
y_meas, x_state = pf.simulate(volmodel, key, n_obs, x_init, theta)

point_plot = pd.DataFrame(jnp.array([
    jnp.arange(y_meas.shape[0]) * _n_res,
    y_meas
]).T, columns = ["Time", "Log Asset Price"])

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 7), sharex = True)

sns.lineplot(data= x_state[..., 1].reshape(_n_res*n_obs, 1)[(_n_res-1):].squeeze(),
             ax = ax[0], linewidth=0.7,
             label = "Price").set(title ="$X_t$", ylabel="Price")
sns.scatterplot(x = "Time", y = "Log Asset Price", 
                data = point_plot,
                color = "firebrick",
                ax = ax[0],
                s=5,
                label="Observed").set(title ="$X_t$")

sns.lineplot(data= x_state[..., 0].reshape(_n_res*n_obs,1)[(_n_res-1):].squeeze(),
             ax = ax[1], alpha = 0.9, linewidth=0.7, color = "firebrick",
             label = "Volatility").set(xlabel="Time",title = "$Z_t$", ylabel="Volatility");

# %%
num_particles = 1000

pf_jit = jax.jit(partial(
    pf.particle_filter,
    model = volmodel,
    key = random.PRNGKey(0),
    y_meas = y_meas,
    theta = theta,
    history=True
), static_argnames="n_particles")

multinom_pf = pf_jit(n_particles=num_particles)

# %%
def quantile_index (logw, q):
    """
    Returns the index of the q-th quantile of logw
    """
    w = pf.utils.logw_to_prob(logw)
    val = jnp.quantile(w, q=q)
    nearest_ind = jnp.argmin(jnp.abs(val - w)) # find index of closest point to val
    return nearest_ind

est_vol_mean = jax.vmap(
    lambda x, w: jnp.average(x, axis=0, weights=pf.utils.logw_to_prob(w)),
    in_axes = (0, 0))(multinom_pf["x_particles"][1:, ..., 0],
                      multinom_pf["logw"][1:, ...])

est_vol_lower = jax.vmap(
    lambda x, logw: x[quantile_index(logw, q=0.025)],
    in_axes = (0, 0))(multinom_pf["x_particles"][1:, ..., 0],
                      multinom_pf["logw"][1:, ...])

est_vol_upper = jax.vmap(
    lambda x, logw: x[quantile_index(logw, q=0.975)],
    in_axes = (0, 0))(multinom_pf["x_particles"][1:, ..., 0],
                      multinom_pf["logw"][1:, ...])

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 7), sharex = True)

sns.lineplot(
    data = x_state[1:, :, 0].flatten(),
    linewidth = 0.9, ax=ax[0],
    label = "True Volatility").set(xlabel="Time",title = "$Z_t$", ylabel="Volatility")
sns.lineplot(data = est_vol_mean.flatten(), 
             color = "firebrick", linewidth = 0.9, 
             alpha = 0.7, ax=ax[0],
             label = "Estimated Volatility")

sns.lineplot(
    data = x_state[1:, :, 0].flatten(), ax=ax[1],
    linewidth=0.9, 
    label = "True Volatility").set(xlabel="Time", ylabel="Volatility")
ax[1].fill_between(
    x = jnp.arange((n_obs-1)*_n_res),
    y1=est_vol_lower.flatten(),
    y2=est_vol_upper.flatten(),
    color = "firebrick",
    label="95% Posterior Bands",
    alpha = 0.3
)
ax[1].legend();

# %%
def particle_gibbs(key, model, n_iter, theta_init, x_state_init, n_particles, rw_sd):
    """
    Sample from the joint posterior distribution of parameters and latent states using a Particle Gibbs sampler.

    Args:
        key: PRNG key.
        n_iter: Number of MCMC iterations.
        theta_init: A vector of `n_params` initial parameter values on the unconstrained scale.
        x_state_init: JAX PyTree of initial state variables.
        n_particles: Number of particles for the particle filter.
        rw_sd: Vector of `n_params` initial standard deviations for the adaptive MWG proposal.

    Returns:
        A dictionary with elements

        - **x_state** - MCMC output for the state variables, with leading dimension `n_iter`.
        - **theta** - MCMC output for the unconstrained parameters, with leading dimension `n_iter`.
        - **accept_rate** - Vector of `n_params` acceptance rates.  These should be close to 0.44.
    """
    # initialize the sampler
    n_params = theta_init.size
    amwg = mcmc.AdaptiveMWG(adapt_max=0.0, adapt_rate=.1)
    # initial state of MWG sampler
    initial_state = {
        "theta": theta_init,
        "x_state": x_state_init,
        "adapt_pars": amwg.init(rw_sd),
    }

    def mcmc_update(key, theta, x_state, adapt_pars):
        """
        MCMC update for parameters and latent variables.

        Use Adaptive MWG for the former and a particle filter for the latter.
        """
        keys = jax.random.split(key, num=3) # two for particle_filter, one for amwg
        # latent variable update
        pf_out = pf.particle_filter(
            model=model,
            key=keys[0],
            y_meas=y_meas,
            theta=theta,
            n_particles=n_particles,
            history=True
        )
        x_state = pf.particle_smooth(
            key=keys[1],
            logw=pf_out["logw"][y_meas.shape[0]-1],
            x_particles=pf_out["x_particles"],
            ancestors=pf_out["resample_out"]["ancestors"]
        )

        # parameter update
        def logpost(theta):
            """
            Log-posterior of the conditional parameter distribution.
            """
            return pf.loglik_full(
                model=model,
                theta=theta,
                x_state=x_state,
                y_meas=y_meas
            )
        theta_state, accept = amwg.step(
            key=keys[2],
            position=theta,
            logprob_fn=logpost,
            rw_sd=adapt_pars["rw_sd"]
        )
        # adapt random walk jump sizes
        adapt_pars = amwg.adapt(pars=adapt_pars, accept=accept)
        return theta_state, x_state, adapt_pars, accept

    @jax.jit
    def step(state, key):
        """
        One step of MCMC update.
        """
        theta, x_state, adapt_pars, accept = mcmc_update(
            key=key,
            theta=state["theta"],
            x_state=state["x_state"],
            adapt_pars=state["adapt_pars"]
        )
        new_state = {
            "theta": theta, 
            "x_state": x_state, 
            "adapt_pars": adapt_pars
        }
        stack_state = {
            "theta": theta, 
            "x_state": x_state
        }
        return new_state, stack_state
    
    keys = jax.random.split(key, num=n_iter)
    state, out = jax.lax.scan(step, initial_state, keys)
    # calculate acceptance rate
    out["accept_rate"] = (1.0 * state["adapt_pars"]["n_accept"]) / n_iter
    return out

# %%
start = time.perf_counter()
n_particles = 500
rw_sd = 0.01 * jnp.ones(4)
n_iter = 5_000

# theta_init = jnp.array([0.02, -0.03, 0.12, 0.008])
theta_init = jnp.array([0.05, -0.05, 0.15, 0.005])

key, subkey = jax.random.split(key)
pg_out = particle_gibbs(
    key=subkey, 
    model=volmodel,
    n_iter=n_iter, 
    theta_init=theta_init, 
    x_state_init=x_state, 
    n_particles=n_particles, 
    rw_sd=rw_sd
)

print("Time: ", time.perf_counter() - start)
pg_out["accept_rate"] # should be close to 0.44
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/interpreters/mlir.py:1122, in _lower_jaxpr_to_fun_cached(ctx, fn_name, call_jaxpr, effects)
#    1121 try:
# -> 1122   func_op = ctx.cached_call_jaxpr_lowerings[key]
#    1123 except KeyError:
#
# KeyError: ('step', { lambda ; a:f32[500] b:i32[499] c:f32[4] d:f32[] e:f32[4] f:f32[4] g:f32[500,5,2]
#     h:u32[2]. let
#     i:key<fry>[] = random_wrap[impl=fry] h
#     j:key<fry>[3] = random_split[count=3] i
#     k:u32[3,2] = random_unwrap j
#     l:u32[1,2] = slice[limit_indices=(1, 2) start_indices=(0, 0) strides=(1, 1)] k
#     m:u32[2] = squeeze[dimensions=(0,)] l
#     n:key<fry>[] = random_wrap[impl=fry] m
#     o:key<fry>[501] = random_split[count=501] n
#     p:u32[501,2] = random_unwrap o
#     q:u32[1,2] = slice[limit_indices=(1, 2) start_indices=(0, 0) strides=(1, 1)] p
#     r:u32[2] = squeeze[dimensions=(0,)] q
#     s:u32[1,2] = slice[limit_indices=(2, 2) start_indices=(1, 0) strides=(1, 1)] p
#     t:u32[2] = squeeze[dimensions=(0,)] s
#     u:u32[1,2] = slice[limit_indices=(3, 2) start_indices=(2, 0) strides=(1, 1)] p
#     v:u32[2] = squeeze[dimensions=(0,)] u
#     w:u32[1,2] = slice[limit_indices=(4, 2) start_indices=(3, 0) strides=(1, 1)] p
#     x:u32[2] = squeeze[dimensions=(0,)] w
#     y:u32[1,2] = slice[limit_indices=(5, 2) start_indices=(4, 0) strides=(1, 1)] p
#     z:u32[2] = squeeze[dimensions=(0,)] y
#     ba:u32[1,2] = slice[
#       limit_indices=(6, 2)
#       start_indices=(5, 0)
#       strides=(1, 1)
#     ] p
#     bb:u32[2] = squeeze[dimensions=(0,)] ba
#     bc:u32[1,2] = slice[
#       limit_indices=(7, 2)
#       start_indices=(6, 0)
#       strides=(1, 1)
#     ] p
#     bd:u32[2] = squeeze[dimensions=(0,)] bc
#     be:u32[1,2] = slice[
#       limit_indices=(8, 2)
#       start_indices=(7, 0)
#       strides=(1, 1)
#     ] p
#     bf:u32[2] = squeeze[dimensions=(0,)] be
#     bg:u32[1,2] = slice[
#       limit_indices=(9, 2)
#       start_indices=(8, 0)
#       strides=(1, 1)
#     ] p
#     bh:u32[2] = squeeze[dimensions=(0,)] bg
#     bi:u32[1,2] = slice[
#       limit_indices=(10, 2)
#       start_indices=(9, 0)
#       strides=(1, 1)
#     ] p
#     bj:u32[2] = squeeze[dimensions=(0,)] bi
#     bk:u32[1,2] = slice[
#       limit_indices=(11, 2)
#       start_indices=(10, 0)
#       strides=(1, 1)
#     ] p
#     bl:u32[2] = squeeze[dimensions=(0,)] bk
#     bm:u32[1,2] = slice[
#       limit_indices=(12, 2)
#       start_indices=(11, 0)
#       strides=(1, 1)
#     ] p
#     bn:u32[2] = squeeze[dimensions=(0,)] bm
#     bo:u32[1,2] = slice[
#       limit_indices=(13, 2)
#       start_indices=(12, 0)
#       strides=(1, 1)
#     ] p
#     bp:u32[2] = squeeze[dimensions=(0,)] bo
#     bq:u32[1,2] = slice[
#       limit_indices=(14, 2)
#       start_indices=(13, 0)
#       strides=(1, 1)
#     ] p
#     br:u32[2] = squeeze[dimensions=(0,)] bq
#     bs:u32[1,2] = slice[
#       limit_indices=(15, 2)
#       start_indices=(14, 0)
#       strides=(1, 1)
#     ] p
#     bt:u32[2] = squeeze[dimensions=(0,)] bs
#     bu:u32[1,2] = slice[
#       limit_indices=(16, 2)
#       start_indices=(15, 0)
#       strides=(1, 1)
#     ] p
#     bv:u32[2] = squeeze[dimensions=(0,)] bu
#     bw:u32[1,2] = slice[
#       limit_indices=(17, 2)
#       start_indices=(16, 0)
#       strides=(1, 1)
#     ] p
#     bx:u32[2] = squeeze[dimensions=(0,)] bw
#     by:u32[1,2] = slice[
#       limit_indices=(18, 2)
#       start_indices=(17, 0)
#       strides=(1, 1)
#     ] p
#     bz:u32[2] = squeeze[dimensions=(0,)] by
#     ca:u32[1,2] = slice[
#       limit_indices=(19, 2)
#       start_indices=(18, 0)
#       strides=(1, 1)
#     ] p
#     cb:u32[2] = squeeze[dimensions=(0,)] ca
#     cc:u32[1,2] = slice[
#       limit_indices=(20, 2)
#       start_indices=(19, 0)
#       strides=(1, 1)
#     ] p
#     cd:u32[2] = squeeze[dimensions=(0,)] cc
#     ce:u32[1,2] = slice[
#       limit_indices=(21, 2)
#       start_indices=(20, 0)
#       strides=(1, 1)
#     ] p
#     cf:u32[2] = squeeze[dimensions=(0,)] ce
#     cg:u32[1,2] = slice[
#       limit_indices=(22, 2)
#       start_indices=(21, 0)
#       strides=(1, 1)
#     ] p
#     ch:u32[2] = squeeze[dimensions=(0,)] cg
#     ci:u32[1,2] = slice[
#       limit_indices=(23, 2)
#       start_indices=(22, 0)
#       strides=(1, 1)
#     ] p
#     cj:u32[2] = squeeze[dimensions=(0,)] ci
#     ck:u32[1,2] = slice[
#       limit_indices=(24, 2)
#       start_indices=(23, 0)
#       strides=(1, 1)
#     ] p
#     cl:u32[2] = squeeze[dimensions=(0,)] ck
#     cm:u32[1,2] = slice[
#       limit_indices=(25, 2)
#       start_indices=(24, 0)
#       strides=(1, 1)
#     ] p
#     cn:u32[2] = squeeze[dimensions=(0,)] cm
#     co:u32[1,2] = slice[
#       limit_indices=(26, 2)
#       start_indices=(25, 0)
#       strides=(1, 1)
#     ] p
#     cp:u32[2] = squeeze[dimensions=(0,)] co
#     cq:u32[1,2] = slice[
#       limit_indices=(27, 2)
#       start_indices=(26, 0)
#       strides=(1, 1)
#     ] p
#     cr:u32[2] = squeeze[dimensions=(0,)] cq
#     cs:u32[1,2] = slice[
#       limit_indices=(28, 2)
#       start_indices=(27, 0)
#       strides=(1, 1)
#     ] p
#     ct:u32[2] = squeeze[dimensions=(0,)] cs
#     cu:u32[1,2] = slice[
#       limit_indices=(29, 2)
#       start_indices=(28, 0)
#       strides=(1, 1)
#     ] p
#     cv:u32[2] = squeeze[dimensions=(0,)] cu
#     cw:u32[1,2] = slice[
#       limit_indices=(30, 2)
#       start_indices=(29, 0)
#       strides=(1, 1)
#     ] p
#     cx:u32[2] = squeeze[dimensions=(0,)] cw
#     cy:u32[1,2] = slice[
#       limit_indices=(31, 2)
#       start_indices=(30, 0)
#       strides=(1, 1)
#     ] p
#     cz:u32[2] = squeeze[dimensions=(0,)] cy
#     da:u32[1,2] = slice[
#       limit_indices=(32, 2)
#       start_indices=(31, 0)
#       strides=(1, 1)
#     ] p
#     db:u32[2] = squeeze[dimensions=(0,)] da
#     dc:u32[1,2] = slice[
#       limit_indices=(33, 2)
#       start_indices=(32, 0)
#       strides=(1, 1)
#     ] p
#     dd:u32[2] = squeeze[dimensions=(0,)] dc
#     de:u32[1,2] = slice[
#       limit_indices=(34, 2)
#       start_indices=(33, 0)
#       strides=(1, 1)
#     ] p
#     df:u32[2] = squeeze[dimensions=(0,)] de
#     dg:u32[1,2] = slice[
#       limit_indices=(35, 2)
#       start_indices=(34, 0)
#       strides=(1, 1)
#     ] p
#     dh:u32[2] = squeeze[dimensions=(0,)] dg
#     di:u32[1,2] = slice[
#       limit_indices=(36, 2)
#       start_indices=(35, 0)
#       strides=(1, 1)
#     ] p
#     dj:u32[2] = squeeze[dimensions=(0,)] di
#     dk:u32[1,2] = slice[
#       limit_indices=(37, 2)
#       start_indices=(36, 0)
#       strides=(1, 1)
#     ] p
#     dl:u32[2] = squeeze[dimensions=(0,)] dk
#     dm:u32[1,2] = slice[
#       limit_indices=(38, 2)
#       start_indices=(37, 0)
#       strides=(1, 1)
#     ] p
#     dn:u32[2] = squeeze[dimensions=(0,)] dm
#     do:u32[1,2] = slice[
#       limit_indices=(39, 2)
#       start_indices=(38, 0)
#       strides=(1, 1)
#     ] p
#     dp:u32[2] = squeeze[dimensions=(0,)] do
#     dq:u32[1,2] = slice[
#       limit_indices=(40, 2)
#       start_indices=(39, 0)
#       strides=(1, 1)
#     ] p
#     dr:u32[2] = squeeze[dimensions=(0,)] dq
#     ds:u32[1,2] = slice[
#       limit_indices=(41, 2)
#       start_indices=(40, 0)
#       strides=(1, 1)
#     ] p
#     dt:u32[2] = squeeze[dimensions=(0,)] ds
#     du:u32[1,2] = slice[
#       limit_indices=(42, 2)
#       start_indices=(41, 0)
#       strides=(1, 1)
#     ] p
#     dv:u32[2] = squeeze[dimensions=(0,)] du
#     dw:u32[1,2] = slice[
#       limit_indices=(43, 2)
#       start_indices=(42, 0)
#       strides=(1, 1)
#     ] p
#     dx:u32[2] = squeeze[dimensions=(0,)] dw
#     dy:u32[1,2] = slice[
#       limit_indices=(44, 2)
#       start_indices=(43, 0)
#       strides=(1, 1)
#     ] p
#     dz:u32[2] = squeeze[dimensions=(0,)] dy
#     ea:u32[1,2] = slice[
#       limit_indices=(45, 2)
#       start_indices=(44, 0)
#       strides=(1, 1)
#     ] p
#     eb:u32[2] = squeeze[dimensions=(0,)] ea
#     ec:u32[1,2] = slice[
#       limit_indices=(46, 2)
#       start_indices=(45, 0)
#       strides=(1, 1)
#     ] p
#     ed:u32[2] = squeeze[dimensions=(0,)] ec
#     ee:u32[1,2] = slice[
#       limit_indices=(47, 2)
#       start_indices=(46, 0)
#       strides=(1, 1)
#     ] p
#     ef:u32[2] = squeeze[dimensions=(0,)] ee
#     eg:u32[1,2] = slice[
#       limit_indices=(48, 2)
#       start_indices=(47, 0)
#       strides=(1, 1)
#     ] p
#     eh:u32[2] = squeeze[dimensions=(0,)] eg
#     ei:u32[1,2] = slice[
#       limit_indices=(49, 2)
#       start_indices=(48, 0)
#       strides=(1, 1)
#     ] p
#     ej:u32[2] = squeeze[dimensions=(0,)] ei
#     ek:u32[1,2] = slice[
#       limit_indices=(50, 2)
#       start_indices=(49, 0)
#       strides=(1, 1)
#     ] p
#     el:u32[2] = squeeze[dimensions=(0,)] ek
#     em:u32[1,2] = slice[
#       limit_indices=(51, 2)
#       start_indices=(50, 0)
#       strides=(1, 1)
#     ] p
#     en:u32[2] = squeeze[dimensions=(0,)] em
#     eo:u32[1,2] = slice[
#       limit_indices=(52, 2)
#       start_indices=(51, 0)
#       strides=(1, 1)
#     ] p
#     ep:u32[2] = squeeze[dimensions=(0,)] eo
#     eq:u32[1,2] = slice[
#       limit_indices=(53, 2)
#       start_indices=(52, 0)
#       strides=(1, 1)
#     ] p
#     er:u32[2] = squeeze[dimensions=(0,)] eq
#     es:u32[1,2] = slice[
#       limit_indices=(54, 2)
#       start_indices=(53, 0)
#       strides=(1, 1)
#     ] p
#     et:u32[2] = squeeze[dimensions=(0,)] es
#     eu:u32[1,2] = slice[
#       limit_indices=(55, 2)
#       start_indices=(54, 0)
#       strides=(1, 1)
#     ] p
#     ev:u32[2] = squeeze[dimensions=(0,)] eu
#     ew:u32[1,2] = slice[
#       limit_indices=(56, 2)
#       start_indices=(55, 0)
#       strides=(1, 1)
#     ] p
#     ex:u32[2] = squeeze[dimensions=(0,)] ew
#     ey:u32[1,2] = slice[
#       limit_indices=(57, 2)
#       start_indices=(56, 0)
#       strides=(1, 1)
#     ] p
#     ez:u32[2] = squeeze[dimensions=(0,)] ey
#     fa:u32[1,2] = slice[
#       limit_indices=(58, 2)
#       start_indices=(57, 0)
#       strides=(1, 1)
#     ] p
#     fb:u32[2] = squeeze[dimensions=(0,)] fa
#     fc:u32[1,2] = slice[
#       limit_indices=(59, 2)
#       start_indices=(58, 0)
#       strides=(1, 1)
#     ] p
#     fd:u32[2] = squeeze[dimensions=(0,)] fc
#     fe:u32[1,2] = slice[
#       limit_indices=(60, 2)
#       start_indices=(59, 0)
#       strides=(1, 1)
#     ] p
#     ff:u32[2] = squeeze[dimensions=(0,)] fe
#     fg:u32[1,2] = slice[
#       limit_indices=(61, 2)
#       start_indices=(60, 0)
#       strides=(1, 1)
#     ] p
#     fh:u32[2] = squeeze[dimensions=(0,)] fg
#     fi:u32[1,2] = slice[
#       limit_indices=(62, 2)
#       start_indices=(61, 0)
#       strides=(1, 1)
#     ] p
#     fj:u32[2] = squeeze[dimensions=(0,)] fi
#     fk:u32[1,2] = slice[
#       limit_indices=(63, 2)
#       start_indices=(62, 0)
#       strides=(1, 1)
#     ] p
#     fl:u32[2] = squeeze[dimensions=(0,)] fk
#     fm:u32[1,2] = slice[
#       limit_indices=(64, 2)
#       start_indices=(63, 0)
#       strides=(1, 1)
#     ] p
#     fn:u32[2] = squeeze[dimensions=(0,)] fm
#     fo:u32[1,2] = slice[
#       limit_indices=(65, 2)
#       start_indices=(64, 0)
#       strides=(1, 1)
#     ] p
#     fp:u32[2] = squeeze[dimensions=(0,)] fo
#     fq:u32[1,2] = slice[
#       limit_indices=(66, 2)
#       start_indices=(65, 0)
#       strides=(1, 1)
#     ] p
#     fr:u32[2] = squeeze[dimensions=(0,)] fq
#     fs:u32[1,2] = slice[
#       limit_indices=(67, 2)
#       start_indices=(66, 0)
#       strides=(1, 1)
#     ] p
#     ft:u32[2] = squeeze[dimensions=(0,)] fs
#     fu:u32[1,2] = slice[
#       limit_indices=(68, 2)
#       start_indices=(67, 0)
#       strides=(1, 1)
#     ] p
#     fv:u32[2] = squeeze[dimensions=(0,)] fu
#     fw:u32[1,2] = slice[
#       limit_indices=(69, 2)
#       start_indices=(68, 0)
#       strides=(1, 1)
#     ] p
#     fx:u32[2] = squeeze[dimensions=(0,)] fw
#     fy:u32[1,2] = slice[
#       limit_indices=(70, 2)
#       start_indices=(69, 0)
#       strides=(1, 1)
#     ] p
#     fz:u32[2] = squeeze[dimensions=(0,)] fy
#     ga:u32[1,2] = slice[
#       limit_indices=(71, 2)
#       start_indices=(70, 0)
#       strides=(1, 1)
#     ] p
#     gb:u32[2] = squeeze[dimensions=(0,)] ga
#     gc:u32[1,2] = slice[
#       limit_indices=(72, 2)
#       start_indices=(71, 0)
#       strides=(1, 1)
#     ] p
#     gd:u32[2] = squeeze[dimensions=(0,)] gc
#     ge:u32[1,2] = slice[
#       limit_indices=(73, 2)
#       start_indices=(72, 0)
#       strides=(1, 1)
#     ] p
#     gf:u32[2] = squeeze[dimensions=(0,)] ge
#     gg:u32[1,2] = slice[
#       limit_indices=(74, 2)
#       start_indices=(73, 0)
#       strides=(1, 1)
#     ] p
#     gh:u32[2] = squeeze[dimensions=(0,)] gg
#     gi:u32[1,2] = slice[
#       limit_indices=(75, 2)
#       start_indices=(74, 0)
#       strides=(1, 1)
#     ] p
#     gj:u32[2] = squeeze[dimensions=(0,)] gi
#     gk:u32[1,2] = slice[
#       limit_indices=(76, 2)
#       start_indices=(75, 0)
#       strides=(1, 1)
#     ] p
#     gl:u32[2] = squeeze[dimensions=(0,)] gk
#     gm:u32[1,2] = slice[
#       limit_indices=(77, 2)
#       start_indices=(76, 0)
#       strides=(1, 1)
#     ] p
#     gn:u32[2] = squeeze[dimensions=(0,)] gm
#     go:u32[1,2] = slice[
#       limit_indices=(78, 2)
#       start_indices=(77, 0)
#       strides=(1, 1)
#     ] p
#     gp:u32[2] = squeeze[dimensions=(0,)] go
#     gq:u32[1,2] = slice[
#       limit_indices=(79, 2)
#       start_indices=(78, 0)
#       strides=(1, 1)
#     ] p
#     gr:u32[2] = squeeze[dimensions=(0,)] gq
#     gs:u32[1,2] = slice[
#       limit_indices=(80, 2)
#       start_indices=(79, 0)
#       strides=(1, 1)
#     ] p
#     gt:u32[2] = squeeze[dimensions=(0,)] gs
#     gu:u32[1,2] = slice[
#       limit_indices=(81, 2)
#       start_indices=(80, 0)
#       strides=(1, 1)
#     ] p
#     gv:u32[2] = squeeze[dimensions=(0,)] gu
#     gw:u32[1,2] = slice[
#       limit_indices=(82, 2)
#       start_indices=(81, 0)
#       strides=(1, 1)
#     ] p
#     gx:u32[2] = squeeze[dimensions=(0,)] gw
#     gy:u32[1,2] = slice[
#       limit_indices=(83, 2)
#       start_indices=(82, 0)
#       strides=(1, 1)
#     ] p
#     gz:u32[2] = squeeze[dimensions=(0,)] gy
#     ha:u32[1,2] = slice[
#       limit_indices=(84, 2)
#       start_indices=(83, 0)
#       strides=(1, 1)
#     ] p
#     hb:u32[2] = squeeze[dimensions=(0,)] ha
#     hc:u32[1,2] = slice[
#       limit_indices=(85, 2)
#       start_indices=(84, 0)
#       strides=(1, 1)
#     ] p
#     hd:u32[2] = squeeze[dimensions=(0,)] hc
#     he:u32[1,2] = slice[
#       limit_indices=(86, 2)
#       start_indices=(85, 0)
#       strides=(1, 1)
#     ] p
#     hf:u32[2] = squeeze[dimensions=(0,)] he
#     hg:u32[1,2] = slice[
#       limit_indices=(87, 2)
#       start_indices=(86, 0)
#       strides=(1, 1)
#     ] p
#     hh:u32[2] = squeeze[dimensions=(0,)] hg
#     hi:u32[1,2] = slice[
#       limit_indices=(88, 2)
#       start_indices=(87, 0)
#       strides=(1, 1)
#     ] p
#     hj:u32[2] = squeeze[dimensions=(0,)] hi
#     hk:u32[1,2] = slice[
#       limit_indices=(89, 2)
#       start_indices=(88, 0)
#       strides=(1, 1)
#     ] p
#     hl:u32[2] = squeeze[dimensions=(0,)] hk
#     hm:u32[1,2] = slice[
#       limit_indices=(90, 2)
#       start_indices=(89, 0)
#       strides=(1, 1)
#     ] p
#     hn:u32[2] = squeeze[dimensions=(0,)] hm
#     ho:u32[1,2] = slice[
#       limit_indices=(91, 2)
#       start_indices=(90, 0)
#       strides=(1, 1)
#     ] p
#     hp:u32[2] = squeeze[dimensions=(0,)] ho
#     hq:u32[1,2] = slice[
#       limit_indices=(92, 2)
#       start_indices=(91, 0)
#       strides=(1, 1)
#     ] p
#     hr:u32[2] = squeeze[dimensions=(0,)] hq
#     hs:u32[1,2] = slice[
#       limit_indices=(93, 2)
#       start_indices=(92, 0)
#       strides=(1, 1)
#     ] p
#     ht:u32[2] = squeeze[dimensions=(0,)] hs
#     hu:u32[1,2] = slice[
#       limit_indices=(94, 2)
#       start_indices=(93, 0)
#       strides=(1, 1)
#     ] p
#     hv:u32[2] = squeeze[dimensions=(0,)] hu
#     hw:u32[1,2] = slice[
#       limit_indices=(95, 2)
#       start_indices=(94, 0)
#       strides=(1, 1)
#     ] p
#     hx:u32[2] = squeeze[dimensions=(0,)] hw
#     hy:u32[1,2] = slice[
#       limit_indices=(96, 2)
#       start_indices=(95, 0)
#       strides=(1, 1)
#     ] p
#     hz:u32[2] = squeeze[dimensions=(0,)] hy
#     ia:u32[1,2] = slice[
#       limit_indices=(97, 2)
#       start_indices=(96, 0)
#       strides=(1, 1)
#     ] p
#     ib:u32[2] = squeeze[dimensions=(0,)] ia
#     ic:u32[1,2] = slice[
#       limit_indices=(98, 2)
#       start_indices=(97, 0)
#       strides=(1, 1)
#     ] p
#     id:u32[2] = squeeze[dimensions=(0,)] ic
#     ie:u32[1,2] = slice[
#       limit_indices=(99, 2)
#       start_indices=(98, 0)
#       strides=(1, 1)
#     ] p
#     if:u32[2] = squeeze[dimensions=(0,)] ie
#     ig:u32[1,2] = slice[
#       limit_indices=(100, 2)
#       start_indices=(99, 0)
#       strides=(1, 1)
#     ] p
#     ih:u32[2] = squeeze[dimensions=(0,)] ig
#     ii:u32[1,2] = slice[
#       limit_indices=(101, 2)
#       start_indices=(100, 0)
#       strides=(1, 1)
#     ] p
#     ij:u32[2] = squeeze[dimensions=(0,)] ii
#     ik:u32[1,2] = slice[
#       limit_indices=(102, 2)
#       start_indices=(101, 0)
#       strides=(1, 1)
#     ] p
#     il:u32[2] = squeeze[dimensions=(0,)] ik
#     im:u32[1,2] = slice[
#       limit_indices=(103, 2)
#       start_indices=(102, 0)
#       strides=(1, 1)
#     ] p
#     in:u32[2] = squeeze[dimensions=(0,)] im
#     io:u32[1,2] = slice[
#       limit_indices=(104, 2)
#       start_indices=(103, 0)
#       strides=(1, 1)
#     ] p
#     ip:u32[2] = squeeze[dimensions=(0,)] io
#     iq:u32[1,2] = slice[
#       limit_indices=(105, 2)
#       start_indices=(104, 0)
#       strides=(1, 1)
#     ] p
#     ir:u32[2] = squeeze[dimensions=(0,)] iq
#     is:u32[1,2] = slice[
#       limit_indices=(106, 2)
#       start_indices=(105, 0)
#       strides=(1, 1)
#     ] p
#     it:u32[2] = squeeze[dimensions=(0,)] is
#     iu:u32[1,2] = slice[
#       limit_indices=(107, 2)
#       start_indices=(106, 0)
#       strides=(1, 1)
#     ] p
#     iv:u32[2] = squeeze[dimensions=(0,)] iu
#     iw:u32[1,2] = slice[
#       limit_indices=(108, 2)
#       start_indices=(107, 0)
#       strides=(1, 1)
#     ] p
#     ix:u32[2] = squeeze[dimensions=(0,)] iw
#     iy:u32[1,2] = slice[
#       limit_indices=(109, 2)
#       start_indices=(108, 0)
#       strides=(1, 1)
#     ] p
#     iz:u32[2] = squeeze[dimensions=(0,)] iy
#     ja:u32[1,2] = slice[
#       limit_indices=(110, 2)
#       start_indices=(109, 0)
#       strides=(1, 1)
#     ] p
#     jb:u32[2] = squeeze[dimensions=(0,)] ja
#     jc:u32[1,2] = slice[
#       limit_indices=(111, 2)
#       start_indices=(110, 0)
#       strides=(1, 1)
#     ] p
#     jd:u32[2] = squeeze[dimensions=(0,)] jc
#     je:u32[1,2] = slice[
#       limit_indices=(112, 2)
#       start_indices=(111, 0)
#       strides=(1, 1)
#     ] p
#     jf:u32[2] = squeeze[dimensions=(0,)] je
#     jg:u32[1,2] = slice[
#       limit_indices=(113, 2)
#       start_indices=(112, 0)
#       strides=(1, 1)
#     ] p
#     jh:u32[2] = squeeze[dimensions=(0,)] jg
#     ji:u32[1,2] = slice[
#       limit_indices=(114, 2)
#       start_indices=(113, 0)
#       strides=(1, 1)
#     ] p
#     jj:u32[2] = squeeze[dimensions=(0,)] ji
#     jk:u32[1,2] = slice[
#       limit_indices=(115, 2)
#       start_indices=(114, 0)
#       strides=(1, 1)
#     ] p
#     jl:u32[2] = squeeze[dimensions=(0,)] jk
#     jm:u32[1,2] = slice[
#       limit_indices=(116, 2)
#       start_indices=(115, 0)
#       strides=(1, 1)
#     ] p
#     jn:u32[2] = squeeze[dimensions=(0,)] jm
#     jo:u32[1,2] = slice[
#       limit_indices=(117, 2)
#       start_indices=(116, 0)
#       strides=(1, 1)
#     ] p
#     jp:u32[2] = squeeze[dimensions=(0,)] jo
#     jq:u32[1,2] = slice[
#       limit_indices=(118, 2)
#       start_indices=(117, 0)
#       strides=(1, 1)
#     ] p
#     jr:u32[2] = squeeze[dimensions=(0,)] jq
#     js:u32[1,2] = slice[
#       limit_indices=(119, 2)
#       start_indices=(118, 0)
#       strides=(1, 1)
#     ] p
#     jt:u32[2] = squeeze[dimensions=(0,)] js
#     ju:u32[1,2] = slice[
#       limit_indices=(120, 2)
#       start_indices=(119, 0)
#       strides=(1, 1)
#     ] p
#     jv:u32[2] = squeeze[dimensions=(0,)] ju
#     jw:u32[1,2] = slice[
#       limit_indices=(121, 2)
#       start_indices=(120, 0)
#       strides=(1, 1)
#     ] p
#     jx:u32[2] = squeeze[dimensions=(0,)] jw
#     jy:u32[1,2] = slice[
#       limit_indices=(122, 2)
#       start_indices=(121, 0)
#       strides=(1, 1)
#     ] p
#     jz:u32[2] = squeeze[dimensions=(0,)] jy
#     ka:u32[1,2] = slice[
#       limit_indices=(123, 2)
#       start_indices=(122, 0)
#       strides=(1, 1)
#     ] p
#     kb:u32[2] = squeeze[dimensions=(0,)] ka
#     kc:u32[1,2] = slice[
#       limit_indices=(124, 2)
#       start_indices=(123, 0)
#       strides=(1, 1)
#     ] p
#     kd:u32[2] = squeeze[dimensions=(0,)] kc
#     ke:u32[1,2] = slice[
#       limit_indices=(125, 2)
#       start_indices=(124, 0)
#       strides=(1, 1)
#     ] p
#     kf:u32[2] = squeeze[dimensions=(0,)] ke
#     kg:u32[1,2] = slice[
#       limit_indices=(126, 2)
#       start_indices=(125, 0)
#       strides=(1, 1)
#     ] p
#     kh:u32[2] = squeeze[dimensions=(0,)] kg
#     ki:u32[1,2] = slice[
#       limit_indices=(127, 2)
#       start_indices=(126, 0)
#       strides=(1, 1)
#     ] p
#     kj:u32[2] = squeeze[dimensions=(0,)] ki
#     kk:u32[1,2] = slice[
#       limit_indices=(128, 2)
#       start_indices=(127, 0)
#       strides=(1, 1)
#     ] p
#     kl:u32[2] = squeeze[dimensions=(0,)] kk
#     km:u32[1,2] = slice[
#       limit_indices=(129, 2)
#       start_indices=(128, 0)
#       strides=(1, 1)
#     ] p
#     kn:u32[2] = squeeze[dimensions=(0,)] km
#     ko:u32[1,2] = slice[
#       limit_indices=(130, 2)
#       start_indices=(129, 0)
#       strides=(1, 1)
#     ] p
#     kp:u32[2] = squeeze[dimensions=(0,)] ko
#     kq:u32[1,2] = slice[
#       limit_indices=(131, 2)
#       start_indices=(130, 0)
#       strides=(1, 1)
#     ] p
#     kr:u32[2] = squeeze[dimensions=(0,)] kq
#     ks:u32[1,2] = slice[
#       limit_indices=(132, 2)
#       start_indices=(131, 0)
#       strides=(1, 1)
#     ] p
#     kt:u32[2] = squeeze[dimensions=(0,)] ks
#     ku:u32[1,2] = slice[
#       limit_indices=(133, 2)
#       start_indices=(132, 0)
#       strides=(1, 1)
#     ] p
#     kv:u32[2] = squeeze[dimensions=(0,)] ku
#     kw:u32[1,2] = slice[
#       limit_indices=(134, 2)
#       start_indices=(133, 0)
#       strides=(1, 1)
#     ] p
#     kx:u32[2] = squeeze[dimensions=(0,)] kw
#     ky:u32[1,2] = slice[
#       limit_indices=(135, 2)
#       start_indices=(134, 0)
#       strides=(1, 1)
#     ] p
#     kz:u32[2] = squeeze[dimensions=(0,)] ky
#     la:u32[1,2] = slice[
#       limit_indices=(136, 2)
#       start_indices=(135, 0)
#       strides=(1, 1)
#     ] p
#     lb:u32[2] = squeeze[dimensions=(0,)] la
#     lc:u32[1,2] = slice[
#       limit_indices=(137, 2)
#       start_indices=(136, 0)
#       strides=(1, 1)
#     ] p
#     ld:u32[2] = squeeze[dimensions=(0,)] lc
#     le:u32[1,2] = slice[
#       limit_indices=(138, 2)
#       start_indices=(137, 0)
#       strides=(1, 1)
#     ] p
#     lf:u32[2] = squeeze[dimensions=(0,)] le
#     lg:u32[1,2] = slice[
#       limit_indices=(139, 2)
#       start_indices=(138, 0)
#       strides=(1, 1)
#     ] p
#     lh:u32[2] = squeeze[dimensions=(0,)] lg
#     li:u32[1,2] = slice[
#       limit_indices=(140, 2)
#       start_indices=(139, 0)
#       strides=(1, 1)
#     ] p
#     lj:u32[2] = squeeze[dimensions=(0,)] li
#     lk:u32[1,2] = slice[
#       limit_indices=(141, 2)
#       start_indices=(140, 0)
#       strides=(1, 1)
#     ] p
#     ll:u32[2] = squeeze[dimensions=(0,)] lk
#     lm:u32[1,2] = slice[
#       limit_indices=(142, 2)
#       start_indices=(141, 0)
#       strides=(1, 1)
#     ] p
#     ln:u32[2] = squeeze[dimensions=(0,)] lm
#     lo:u32[1,2] = slice[
#       limit_indices=(143, 2)
#       start_indices=(142, 0)
#       strides=(1, 1)
#     ] p
#     lp:u32[2] = squeeze[dimensions=(0,)] lo
#     lq:u32[1,2] = slice[
#       limit_indices=(144, 2)
#       start_indices=(143, 0)
#       strides=(1, 1)
#     ] p
#     lr:u32[2] = squeeze[dimensions=(0,)] lq
#     ls:u32[1,2] = slice[
#       limit_indices=(145, 2)
#       start_indices=(144, 0)
#       strides=(1, 1)
#     ] p
#     lt:u32[2] = squeeze[dimensions=(0,)] ls
#     lu:u32[1,2] = slice[
#       limit_indices=(146, 2)
#       start_indices=(145, 0)
#       strides=(1, 1)
#     ] p
#     lv:u32[2] = squeeze[dimensions=(0,)] lu
#     lw:u32[1,2] = slice[
#       limit_indices=(147, 2)
#       start_indices=(146, 0)
#       strides=(1, 1)
#     ] p
#     lx:u32[2] = squeeze[dimensions=(0,)] lw
#     ly:u32[1,2] = slice[
#       limit_indices=(148, 2)
#       start_indices=(147, 0)
#       strides=(1, 1)
#     ] p
#     lz:u32[2] = squeeze[dimensions=(0,)] ly
#     ma:u32[1,2] = slice[
#       limit_indices=(149, 2)
#       start_indices=(148, 0)
#       strides=(1, 1)
#     ] p
#     mb:u32[2] = squeeze[dimensions=(0,)] ma
#     mc:u32[1,2] = slice[
#       limit_indices=(150, 2)
#       start_indices=(149, 0)
#       strides=(1, 1)
#     ] p
#     md:u32[2] = squeeze[dimensions=(0,)] mc
#     me:u32[1,2] = slice[
#       limit_indices=(151, 2)
#       start_indices=(150, 0)
#       strides=(1, 1)
#     ] p
#     mf:u32[2] = squeeze[dimensions=(0,)] me
#     mg:u32[1,2] = slice[
#       limit_indices=(152, 2)
#       start_indices=(151, 0)
#       strides=(1, 1)
#     ] p
#     mh:u32[2] = squeeze[dimensions=(0,)] mg
#     mi:u32[1,2] = slice[
#       limit_indices=(153, 2)
#       start_indices=(152, 0)
#       strides=(1, 1)
#     ] p
#     mj:u32[2] = squeeze[dimensions=(0,)] mi
#     mk:u32[1,2] = slice[
#       limit_indices=(154, 2)
#       start_indices=(153, 0)
#       strides=(1, 1)
#     ] p
#     ml:u32[2] = squeeze[dimensions=(0,)] mk
#     mm:u32[1,2] = slice[
#       limit_indices=(155, 2)
#       start_indices=(154, 0)
#       strides=(1, 1)
#     ] p
#     mn:u32[2] = squeeze[dimensions=(0,)] mm
#     mo:u32[1,2] = slice[
#       limit_indices=(156, 2)
#       start_indices=(155, 0)
#       strides=(1, 1)
#     ] p
#     mp:u32[2] = squeeze[dimensions=(0,)] mo
#     mq:u32[1,2] = slice[
#       limit_indices=(157, 2)
#       start_indices=(156, 0)
#       strides=(1, 1)
#     ] p
#     mr:u32[2] = squeeze[dimensions=(0,)] mq
#     ms:u32[1,2] = slice[
#       limit_indices=(158, 2)
#       start_indices=(157, 0)
#       strides=(1, 1)
#     ] p
#     mt:u32[2] = squeeze[dimensions=(0,)] ms
#     mu:u32[1,2] = slice[
#       limit_indices=(159, 2)
#       start_indices=(158, 0)
#       strides=(1, 1)
#     ] p
#     mv:u32[2] = squeeze[dimensions=(0,)] mu
#     mw:u32[1,2] = slice[
#       limit_indices=(160, 2)
#       start_indices=(159, 0)
#       strides=(1, 1)
#     ] p
#     mx:u32[2] = squeeze[dimensions=(0,)] mw
#     my:u32[1,2] = slice[
#       limit_indices=(161, 2)
#       start_indices=(160, 0)
#       strides=(1, 1)
#     ] p
#     mz:u32[2] = squeeze[dimensions=(0,)] my
#     na:u32[1,2] = slice[
#       limit_indices=(162, 2)
#       start_indices=(161, 0)
#       strides=(1, 1)
#     ] p
#     nb:u32[2] = squeeze[dimensions=(0,)] na
#     nc:u32[1,2] = slice[
#       limit_indices=(163, 2)
#       start_indices=(162, 0)
#       strides=(1, 1)
#     ] p
#     nd:u32[2] = squeeze[dimensions=(0,)] nc
#     ne:u32[1,2] = slice[
#       limit_indices=(164, 2)
#       start_indices=(163, 0)
#       strides=(1, 1)
#     ] p
#     nf:u32[2] = squeeze[dimensions=(0,)] ne
#     ng:u32[1,2] = slice[
#       limit_indices=(165, 2)
#       start_indices=(164, 0)
#       strides=(1, 1)
#     ] p
#     nh:u32[2] = squeeze[dimensions=(0,)] ng
#     ni:u32[1,2] = slice[
#       limit_indices=(166, 2)
#       start_indices=(165, 0)
#       strides=(1, 1)
#     ] p
#     nj:u32[2] = squeeze[dimensions=(0,)] ni
#     nk:u32[1,2] = slice[
#       limit_indices=(167, 2)
#       start_indices=(166, 0)
#       strides=(1, 1)
#     ] p
#     nl:u32[2] = squeeze[dimensions=(0,)] nk
#     nm:u32[1,2] = slice[
#       limit_indices=(168, 2)
#       start_indices=(167, 0)
#       strides=(1, 1)
#     ] p
#     nn:u32[2] = squeeze[dimensions=(0,)] nm
#     no:u32[1,2] = slice[
#       limit_indices=(169, 2)
#       start_indices=(168, 0)
#       strides=(1, 1)
#     ] p
#     np:u32[2] = squeeze[dimensions=(0,)] no
#     nq:u32[1,2] = slice[
#       limit_indices=(170, 2)
#       start_indices=(169, 0)
#       strides=(1, 1)
#     ] p
#     nr:u32[2] = squeeze[dimensions=(0,)] nq
#     ns:u32[1,2] = slice[
#       limit_indices=(171, 2)
#       start_indices=(170, 0)
#       strides=(1, 1)
#     ] p
#     nt:u32[2] = squeeze[dimensions=(0,)] ns
#     nu:u32[1,2] = slice[
#       limit_indices=(172, 2)
#       start_indices=(171, 0)
#       strides=(1, 1)
#     ] p
#     nv:u32[2] = squeeze[dimensions=(0,)] nu
#     nw:u32[1,2] = slice[
#       limit_indices=(173, 2)
#       start_indices=(172, 0)
#       strides=(1, 1)
#     ] p
#     nx:u32[2] = squeeze[dimensions=(0,)] nw
#     ny:u32[1,2] = slice[
#       limit_indices=(174, 2)
#       start_indices=(173, 0)
#       strides=(1, 1)
#     ] p
#     nz:u32[2] = squeeze[dimensions=(0,)] ny
#     oa:u32[1,2] = slice[
#       limit_indices=(175, 2)
#       start_indices=(174, 0)
#       strides=(1, 1)
#     ] p
#     ob:u32[2] = squeeze[dimensions=(0,)] oa
#     oc:u32[1,2] = slice[
#       limit_indices=(176, 2)
#       start_indices=(175, 0)
#       strides=(1, 1)
#     ] p
#     od:u32[2] = squeeze[dimensions=(0,)] oc
#     oe:u32[1,2] = slice[
#       limit_indices=(177, 2)
#       start_indices=(176, 0)
#       strides=(1, 1)
#     ] p
#     of:u32[2] = squeeze[dimensions=(0,)] oe
#     og:u32[1,2] = slice[
#       limit_indices=(178, 2)
#       start_indices=(177, 0)
#       strides=(1, 1)
#     ] p
#     oh:u32[2] = squeeze[dimensions=(0,)] og
#     oi:u32[1,2] = slice[
#       limit_indices=(179, 2)
#       start_indices=(178, 0)
#       strides=(1, 1)
#     ] p
#     oj:u32[2] = squeeze[dimensions=(0,)] oi
#     ok:u32[1,2] = slice[
#       limit_indices=(180, 2)
#       start_indices=(179, 0)
#       strides=(1, 1)
#     ] p
#     ol:u32[2] = squeeze[dimensions=(0,)] ok
#     om:u32[1,2] = slice[
#       limit_indices=(181, 2)
#       start_indices=(180, 0)
#       strides=(1, 1)
#     ] p
#     on:u32[2] = squeeze[dimensions=(0,)] om
#     oo:u32[1,2] = slice[
#       limit_indices=(182, 2)
#       start_indices=(181, 0)
#       strides=(1, 1)
#     ] p
#     op:u32[2] = squeeze[dimensions=(0,)] oo
#     oq:u32[1,2] = slice[
#       limit_indices=(183, 2)
#       start_indices=(182, 0)
#       strides=(1, 1)
#     ] p
#     or:u32[2] = squeeze[dimensions=(0,)] oq
#     os:u32[1,2] = slice[
#       limit_indices=(184, 2)
#       start_indices=(183, 0)
#       strides=(1, 1)
#     ] p
#     ot:u32[2] = squeeze[dimensions=(0,)] os
#     ou:u32[1,2] = slice[
#       limit_indices=(185, 2)
#       start_indices=(184, 0)
#       strides=(1, 1)
#     ] p
#     ov:u32[2] = squeeze[dimensions=(0,)] ou
#     ow:u32[1,2] = slice[
#       limit_indices=(186, 2)
#       start_indices=(185, 0)
#       strides=(1, 1)
#     ] p
#     ox:u32[2] = squeeze[dimensions=(0,)] ow
#     oy:u32[1,2] = slice[
#       limit_indices=(187, 2)
#       start_indices=(186, 0)
#       strides=(1, 1)
#     ] p
#     oz:u32[2] = squeeze[dimensions=(0,)] oy
#     pa:u32[1,2] = slice[
#       limit_indices=(188, 2)
#       start_indices=(187, 0)
#       strides=(1, 1)
#     ] p
#     pb:u32[2] = squeeze[dimensions=(0,)] pa
#     pc:u32[1,2] = slice[
#       limit_indices=(189, 2)
#       start_indices=(188, 0)
#       strides=(1, 1)
#     ] p
#     pd:u32[2] = squeeze[dimensions=(0,)] pc
#     pe:u32[1,2] = slice[
#       limit_indices=(190, 2)
#       start_indices=(189, 0)
#       strides=(1, 1)
#     ] p
#     pf:u32[2] = squeeze[dimensions=(0,)] pe
#     pg:u32[1,2] = slice[
#       limit_indices=(191, 2)
#       start_indices=(190, 0)
#       strides=(1, 1)
#     ] p
#     ph:u32[2] = squeeze[dimensions=(0,)] pg
#     pi:u32[1,2] = slice[
#       limit_indices=(192, 2)
#       start_indices=(191, 0)
#       strides=(1, 1)
#     ] p
#     pj:u32[2] = squeeze[dimensions=(0,)] pi
#     pk:u32[1,2] = slice[
#       limit_indices=(193, 2)
#       start_indices=(192, 0)
#       strides=(1, 1)
#     ] p
#     pl:u32[2] = squeeze[dimensions=(0,)] pk
#     pm:u32[1,2] = slice[
#       limit_indices=(194, 2)
#       start_indices=(193, 0)
#       strides=(1, 1)
#     ] p
#     pn:u32[2] = squeeze[dimensions=(0,)] pm
#     po:u32[1,2] = slice[
#       limit_indices=(195, 2)
#       start_indices=(194, 0)
#       strides=(1, 1)
#     ] p
#     pp:u32[2] = squeeze[dimensions=(0,)] po
#     pq:u32[1,2] = slice[
#       limit_indices=(196, 2)
#       start_indices=(195, 0)
#       strides=(1, 1)
#     ] p
#     pr:u32[2] = squeeze[dimensions=(0,)] pq
#     ps:u32[1,2] = slice[
#       limit_indices=(197, 2)
#       start_indices=(196, 0)
#       strides=(1, 1)
#     ] p
#     pt:u32[2] = squeeze[dimensions=(0,)] ps
#     pu:u32[1,2] = slice[
#       limit_indices=(198, 2)
#       start_indices=(197, 0)
#       strides=(1, 1)
#     ] p
#     pv:u32[2] = squeeze[dimensions=(0,)] pu
#     pw:u32[1,2] = slice[
#       limit_indices=(199, 2)
#       start_indices=(198, 0)
#       strides=(1, 1)
#     ] p
#     px:u32[2] = squeeze[dimensions=(0,)] pw
#     py:u32[1,2] = slice[
#       limit_indices=(200, 2)
#       start_indices=(199, 0)
#       strides=(1, 1)
#     ] p
#     pz:u32[2] = squeeze[dimensions=(0,)] py
#     qa:u32[1,2] = slice[
#       limit_indices=(201, 2)
#       start_indices=(200, 0)
#       strides=(1, 1)
#     ] p
#     qb:u32[2] = squeeze[dimensions=(0,)] qa
#     qc:u32[1,2] = slice[
#       limit_indices=(202, 2)
#       start_indices=(201, 0)
#       strides=(1, 1)
#     ] p
#     qd:u32[2] = squeeze[dimensions=(0,)] qc
#     qe:u32[1,2] = slice[
#       limit_indices=(203, 2)
#       start_indices=(202, 0)
#       strides=(1, 1)
#     ] p
#     qf:u32[2] = squeeze[dimensions=(0,)] qe
#     qg:u32[1,2] = slice[
#       limit_indices=(204, 2)
#       start_indices=(203, 0)
#       strides=(1, 1)
#     ] p
#     qh:u32[2] = squeeze[dimensions=(0,)] qg
#     qi:u32[1,2] = slice[
#       limit_indices=(205, 2)
#       start_indices=(204, 0)
#       strides=(1, 1)
#     ] p
#     qj:u32[2] = squeeze[dimensions=(0,)] qi
#     qk:u32[1,2] = slice[
#       limit_indices=(206, 2)
#       start_indices=(205, 0)
#       strides=(1, 1)
#     ] p
#     ql:u32[2] = squeeze[dimensions=(0,)] qk
#     qm:u32[1,2] = slice[
#       limit_indices=(207, 2)
#       start_indices=(206, 0)
#       strides=(1, 1)
#     ] p
#     qn:u32[2] = squeeze[dimensions=(0,)] qm
#     qo:u32[1,2] = slice[
#       limit_indices=(208, 2)
#       start_indices=(207, 0)
#       strides=(1, 1)
#     ] p
#     qp:u32[2] = squeeze[dimensions=(0,)] qo
#     qq:u32[1,2] = slice[
#       limit_indices=(209, 2)
#       start_indices=(208, 0)
#       strides=(1, 1)
#     ] p
#     qr:u32[2] = squeeze[dimensions=(0,)] qq
#     qs:u32[1,2] = slice[
#       limit_indices=(210, 2)
#       start_indices=(209, 0)
#       strides=(1, 1)
#     ] p
#     qt:u32[2] = squeeze[dimensions=(0,)] qs
#     qu:u32[1,2] = slice[
#       limit_indices=(211, 2)
#       start_indices=(210, 0)
#       strides=(1, 1)
#     ] p
#     qv:u32[2] = squeeze[dimensions=(0,)] qu
#     qw:u32[1,2] = slice[
#       limit_indices=(212, 2)
#       start_indices=(211, 0)
#       strides=(1, 1)
#     ] p
#     qx:u32[2] = squeeze[dimensions=(0,)] qw
#     qy:u32[1,2] = slice[
#       limit_indices=(213, 2)
#       start_indices=(212, 0)
#       strides=(1, 1)
#     ] p
#     qz:u32[2] = squeeze[dimensions=(0,)] qy
#     ra:u32[1,2] = slice[
#       limit_indices=(214, 2)
#       start_indices=(213, 0)
#       strides=(1, 1)
#     ] p
#     rb:u32[2] = squeeze[dimensions=(0,)] ra
#     rc:u32[1,2] = slice[
#       limit_indices=(215, 2)
#       start_indices=(214, 0)
#       strides=(1, 1)
#     ] p
#     rd:u32[2] = squeeze[dimensions=(0,)] rc
#     re:u32[1,2] = slice[
#       limit_indices=(216, 2)
#       start_indices=(215, 0)
#       strides=(1, 1)
#     ] p
#     rf:u32[2] = squeeze[dimensions=(0,)] re
#     rg:u32[1,2] = slice[
#       limit_indices=(217, 2)
#       start_indices=(216, 0)
#       strides=(1, 1)
#     ] p
#     rh:u32[2] = squeeze[dimensions=(0,)] rg
#     ri:u32[1,2] = slice[
#       limit_indices=(218, 2)
#       start_indices=(217, 0)
#       strides=(1, 1)
#     ] p
#     rj:u32[2] = squeeze[dimensions=(0,)] ri
#     rk:u32[1,2] = slice[
#       limit_indices=(219, 2)
#       start_indices=(218, 0)
#       strides=(1, 1)
#     ] p
#     rl:u32[2] = squeeze[dimensions=(0,)] rk
#     rm:u32[1,2] = slice[
#       limit_indices=(220, 2)
#       start_indices=(219, 0)
#       strides=(1, 1)
#     ] p
#     rn:u32[2] = squeeze[dimensions=(0,)] rm
#     ro:u32[1,2] = slice[
#       limit_indices=(221, 2)
#       start_indices=(220, 0)
#       strides=(1, 1)
#     ] p
#     rp:u32[2] = squeeze[dimensions=(0,)] ro
#     rq:u32[1,2] = slice[
#       limit_indices=(222, 2)
#       start_indices=(221, 0)
#       strides=(1, 1)
#     ] p
#     rr:u32[2] = squeeze[dimensions=(0,)] rq
#     rs:u32[1,2] = slice[
#       limit_indices=(223, 2)
#       start_indices=(222, 0)
#       strides=(1, 1)
#     ] p
#     rt:u32[2] = squeeze[dimensions=(0,)] rs
#     ru:u32[1,2] = slice[
#       limit_indices=(224, 2)
#       start_indices=(223, 0)
#       strides=(1, 1)
#     ] p
#     rv:u32[2] = squeeze[dimensions=(0,)] ru
#     rw:u32[1,2] = slice[
#       limit_indices=(225, 2)
#       start_indices=(224, 0)
#       strides=(1, 1)
#     ] p
#     rx:u32[2] = squeeze[dimensions=(0,)] rw
#     ry:u32[1,2] = slice[
#       limit_indices=(226, 2)
#       start_indices=(225, 0)
#       strides=(1, 1)
#     ] p
#     rz:u32[2] = squeeze[dimensions=(0,)] ry
#     sa:u32[1,2] = slice[
#       limit_indices=(227, 2)
#       start_indices=(226, 0)
#       strides=(1, 1)
#     ] p
#     sb:u32[2] = squeeze[dimensions=(0,)] sa
#     sc:u32[1,2] = slice[
#       limit_indices=(228, 2)
#       start_indices=(227, 0)
#       strides=(1, 1)
#     ] p
#     sd:u32[2] = squeeze[dimensions=(0,)] sc
#     se:u32[1,2] = slice[
#       limit_indices=(229, 2)
#       start_indices=(228, 0)
#       strides=(1, 1)
#     ] p
#     sf:u32[2] = squeeze[dimensions=(0,)] se
#     sg:u32[1,2] = slice[
#       limit_indices=(230, 2)
#       start_indices=(229, 0)
#       strides=(1, 1)
#     ] p
#     sh:u32[2] = squeeze[dimensions=(0,)] sg
#     si:u32[1,2] = slice[
#       limit_indices=(231, 2)
#       start_indices=(230, 0)
#       strides=(1, 1)
#     ] p
#     sj:u32[2] = squeeze[dimensions=(0,)] si
#     sk:u32[1,2] = slice[
#       limit_indices=(232, 2)
#       start_indices=(231, 0)
#       strides=(1, 1)
#     ] p
#     sl:u32[2] = squeeze[dimensions=(0,)] sk
#     sm:u32[1,2] = slice[
#       limit_indices=(233, 2)
#       start_indices=(232, 0)
#       strides=(1, 1)
#     ] p
#     sn:u32[2] = squeeze[dimensions=(0,)] sm
#     so:u32[1,2] = slice[
#       limit_indices=(234, 2)
#       start_indices=(233, 0)
#       strides=(1, 1)
#     ] p
#     sp:u32[2] = squeeze[dimensions=(0,)] so
#     sq:u32[1,2] = slice[
#       limit_indices=(235, 2)
#       start_indices=(234, 0)
#       strides=(1, 1)
#     ] p
#     sr:u32[2] = squeeze[dimensions=(0,)] sq
#     ss:u32[1,2] = slice[
#       limit_indices=(236, 2)
#       start_indices=(235, 0)
#       strides=(1, 1)
#     ] p
#     st:u32[2] = squeeze[dimensions=(0,)] ss
#     su:u32[1,2] = slice[
#       limit_indices=(237, 2)
#       start_indices=(236, 0)
#       strides=(1, 1)
#     ] p
#     sv:u32[2] = squeeze[dimensions=(0,)] su
#     sw:u32[1,2] = slice[
#       limit_indices=(238, 2)
#       start_indices=(237, 0)
#       strides=(1, 1)
#     ] p
#     sx:u32[2] = squeeze[dimensions=(0,)] sw
#     sy:u32[1,2] = slice[
#       limit_indices=(239, 2)
#       start_indices=(238, 0)
#       strides=(1, 1)
#     ] p
#     sz:u32[2] = squeeze[dimensions=(0,)] sy
#     ta:u32[1,2] = slice[
#       limit_indices=(240, 2)
#       start_indices=(239, 0)
#       strides=(1, 1)
#     ] p
#     tb:u32[2] = squeeze[dimensions=(0,)] ta
#     tc:u32[1,2] = slice[
#       limit_indices=(241, 2)
#       start_indices=(240, 0)
#       strides=(1, 1)
#     ] p
#     td:u32[2] = squeeze[dimensions=(0,)] tc
#     te:u32[1,2] = slice[
#       limit_indices=(242, 2)
#       start_indices=(241, 0)
#       strides=(1, 1)
#     ] p
#     tf:u32[2] = squeeze[dimensions=(0,)] te
#     tg:u32[1,2] = slice[
#       limit_indices=(243, 2)
#       start_indices=(242, 0)
#       strides=(1, 1)
#     ] p
#     th:u32[2] = squeeze[dimensions=(0,)] tg
#     ti:u32[1,2] = slice[
#       limit_indices=(244, 2)
#       start_indices=(243, 0)
#       strides=(1, 1)
#     ] p
#     tj:u32[2] = squeeze[dimensions=(0,)] ti
#     tk:u32[1,2] = slice[
#       limit_indices=(245, 2)
#       start_indices=(244, 0)
#       strides=(1, 1)
#     ] p
#     tl:u32[2] = squeeze[dimensions=(0,)] tk
#     tm:u32[1,2] = slice[
#       limit_indices=(246, 2)
#       start_indices=(245, 0)
#       strides=(1, 1)
#     ] p
#     tn:u32[2] = squeeze[dimensions=(0,)] tm
#     to:u32[1,2] = slice[
#       limit_indices=(247, 2)
#       start_indices=(246, 0)
#       strides=(1, 1)
#     ] p
#     tp:u32[2] = squeeze[dimensions=(0,)] to
#     tq:u32[1,2] = slice[
#       limit_indices=(248, 2)
#       start_indices=(247, 0)
#       strides=(1, 1)
#     ] p
#     tr:u32[2] = squeeze[dimensions=(0,)] tq
#     ts:u32[1,2] = slice[
#       limit_indices=(249, 2)
#       start_indices=(248, 0)
#       strides=(1, 1)
#     ] p
#     tt:u32[2] = squeeze[dimensions=(0,)] ts
#     tu:u32[1,2] = slice[
#       limit_indices=(250, 2)
#       start_indices=(249, 0)
#       strides=(1, 1)
#     ] p
#     tv:u32[2] = squeeze[dimensions=(0,)] tu
#     tw:u32[1,2] = slice[
#       limit_indices=(251, 2)
#       start_indices=(250, 0)
#       strides=(1, 1)
#     ] p
#     tx:u32[2] = squeeze[dimensions=(0,)] tw
#     ty:u32[1,2] = slice[
#       limit_indices=(252, 2)
#       start_indices=(251, 0)
#       strides=(1, 1)
#     ] p
#     tz:u32[2] = squeeze[dimensions=(0,)] ty
#     ua:u32[1,2] = slice[
#       limit_indices=(253, 2)
#       start_indices=(252, 0)
#       strides=(1, 1)
#     ] p
#     ub:u32[2] = squeeze[dimensions=(0,)] ua
#     uc:u32[1,2] = slice[
#       limit_indices=(254, 2)
#       start_indices=(253, 0)
#       strides=(1, 1)
#     ] p
#     ud:u32[2] = squeeze[dimensions=(0,)] uc
#     ue:u32[1,2] = slice[
#       limit_indices=(255, 2)
#       start_indices=(254, 0)
#       strides=(1, 1)
#     ] p
#     uf:u32[2] = squeeze[dimensions=(0,)] ue
#     ug:u32[1,2] = slice[
#       limit_indices=(256, 2)
#       start_indices=(255, 0)
#       strides=(1, 1)
#     ] p
#     uh:u32[2] = squeeze[dimensions=(0,)] ug
#     ui:u32[1,2] = slice[
#       limit_indices=(257, 2)
#       start_indices=(256, 0)
#       strides=(1, 1)
#     ] p
#     uj:u32[2] = squeeze[dimensions=(0,)] ui
#     uk:u32[1,2] = slice[
#       limit_indices=(258, 2)
#       start_indices=(257, 0)
#       strides=(1, 1)
#     ] p
#     ul:u32[2] = squeeze[dimensions=(0,)] uk
#     um:u32[1,2] = slice[
#       limit_indices=(259, 2)
#       start_indices=(258, 0)
#       strides=(1, 1)
#     ] p
#     un:u32[2] = squeeze[dimensions=(0,)] um
#     uo:u32[1,2] = slice[
#       limit_indices=(260, 2)
#       start_indices=(259, 0)
#       strides=(1, 1)
#     ] p
#     up:u32[2] = squeeze[dimensions=(0,)] uo
#     uq:u32[1,2] = slice[
#       limit_indices=(261, 2)
#       start_indices=(260, 0)
#       strides=(1, 1)
#     ] p
#     ur:u32[2] = squeeze[dimensions=(0,)] uq
#     us:u32[1,2] = slice[
#       limit_indices=(262, 2)
#       start_indices=(261, 0)
#       strides=(1, 1)
#     ] p
#     ut:u32[2] = squeeze[dimensions=(0,)] us
#     uu:u32[1,2] = slice[
#       limit_indices=(263, 2)
#       start_indices=(262, 0)
#       strides=(1, 1)
#     ] p
#     uv:u32[2] = squeeze[dimensions=(0,)] uu
#     uw:u32[1,2] = slice[
#       limit_indices=(264, 2)
#       start_indices=(263, 0)
#       strides=(1, 1)
#     ] p
#     ux:u32[2] = squeeze[dimensions=(0,)] uw
#     uy:u32[1,2] = slice[
#       limit_indices=(265, 2)
#       start_indices=(264, 0)
#       strides=(1, 1)
#     ] p
#     uz:u32[2] = squeeze[dimensions=(0,)] uy
#     va:u32[1,2] = slice[
#       limit_indices=(266, 2)
#       start_indices=(265, 0)
#       strides=(1, 1)
#     ] p
#     vb:u32[2] = squeeze[dimensions=(0,)] va
#     vc:u32[1,2] = slice[
#       limit_indices=(267, 2)
#       start_indices=(266, 0)
#       strides=(1, 1)
#     ] p
#     vd:u32[2] = squeeze[dimensions=(0,)] vc
#     ve:u32[1,2] = slice[
#       limit_indices=(268, 2)
#       start_indices=(267, 0)
#       strides=(1, 1)
#     ] p
#     vf:u32[2] = squeeze[dimensions=(0,)] ve
#     vg:u32[1,2] = slice[
#       limit_indices=(269, 2)
#       start_indices=(268, 0)
#       strides=(1, 1)
#     ] p
#     vh:u32[2] = squeeze[dimensions=(0,)] vg
#     vi:u32[1,2] = slice[
#       limit_indices=(270, 2)
#       start_indices=(269, 0)
#       strides=(1, 1)
#     ] p
#     vj:u32[2] = squeeze[dimensions=(0,)] vi
#     vk:u32[1,2] = slice[
#       limit_indices=(271, 2)
#       start_indices=(270, 0)
#       strides=(1, 1)
#     ] p
#     vl:u32[2] = squeeze[dimensions=(0,)] vk
#     vm:u32[1,2] = slice[
#       limit_indices=(272, 2)
#       start_indices=(271, 0)
#       strides=(1, 1)
#     ] p
#     vn:u32[2] = squeeze[dimensions=(0,)] vm
#     vo:u32[1,2] = slice[
#       limit_indices=(273, 2)
#       start_indices=(272, 0)
#       strides=(1, 1)
#     ] p
#     vp:u32[2] = squeeze[dimensions=(0,)] vo
#     vq:u32[1,2] = slice[
#       limit_indices=(274, 2)
#       start_indices=(273, 0)
#       strides=(1, 1)
#     ] p
#     vr:u32[2] = squeeze[dimensions=(0,)] vq
#     vs:u32[1,2] = slice[
#       limit_indices=(275, 2)
#       start_indices=(274, 0)
#       strides=(1, 1)
#     ] p
#     vt:u32[2] = squeeze[dimensions=(0,)] vs
#     vu:u32[1,2] = slice[
#       limit_indices=(276, 2)
#       start_indices=(275, 0)
#       strides=(1, 1)
#     ] p
#     vv:u32[2] = squeeze[dimensions=(0,)] vu
#     vw:u32[1,2] = slice[
#       limit_indices=(277, 2)
#       start_indices=(276, 0)
#       strides=(1, 1)
#     ] p
#     vx:u32[2] = squeeze[dimensions=(0,)] vw
#     vy:u32[1,2] = slice[
#       limit_indices=(278, 2)
#       start_indices=(277, 0)
#       strides=(1, 1)
#     ] p
#     vz:u32[2] = squeeze[dimensions=(0,)] vy
#     wa:u32[1,2] = slice[
#       limit_indices=(279, 2)
#       start_indices=(278, 0)
#       strides=(1, 1)
#     ] p
#     wb:u32[2] = squeeze[dimensions=(0,)] wa
#     wc:u32[1,2] = slice[
#       limit_indices=(280, 2)
#       start_indices=(279, 0)
#       strides=(1, 1)
#     ] p
#     wd:u32[2] = squeeze[dimensions=(0,)] wc
#     we:u32[1,2] = slice[
#       limit_indices=(281, 2)
#       start_indices=(280, 0)
#       strides=(1, 1)
#     ] p
#     wf:u32[2] = squeeze[dimensions=(0,)] we
#     wg:u32[1,2] = slice[
#       limit_indices=(282, 2)
#       start_indices=(281, 0)
#       strides=(1, 1)
#     ] p
#     wh:u32[2] = squeeze[dimensions=(0,)] wg
#     wi:u32[1,2] = slice[
#       limit_indices=(283, 2)
#       start_indices=(282, 0)
#       strides=(1, 1)
#     ] p
#     wj:u32[2] = squeeze[dimensions=(0,)] wi
#     wk:u32[1,2] = slice[
#       limit_indices=(284, 2)
#       start_indices=(283, 0)
#       strides=(1, 1)
#     ] p
#     wl:u32[2] = squeeze[dimensions=(0,)] wk
#     wm:u32[1,2] = slice[
#       limit_indices=(285, 2)
#       start_indices=(284, 0)
#       strides=(1, 1)
#     ] p
#     wn:u32[2] = squeeze[dimensions=(0,)] wm
#     wo:u32[1,2] = slice[
#       limit_indices=(286, 2)
#       start_indices=(285, 0)
#       strides=(1, 1)
#     ] p
#     wp:u32[2] = squeeze[dimensions=(0,)] wo
#     wq:u32[1,2] = slice[
#       limit_indices=(287, 2)
#       start_indices=(286, 0)
#       strides=(1, 1)
#     ] p
#     wr:u32[2] = squeeze[dimensions=(0,)] wq
#     ws:u32[1,2] = slice[
#       limit_indices=(288, 2)
#       start_indices=(287, 0)
#       strides=(1, 1)
#     ] p
#     wt:u32[2] = squeeze[dimensions=(0,)] ws
#     wu:u32[1,2] = slice[
#       limit_indices=(289, 2)
#       start_indices=(288, 0)
#       strides=(1, 1)
#     ] p
#     wv:u32[2] = squeeze[dimensions=(0,)] wu
#     ww:u32[1,2] = slice[
#       limit_indices=(290, 2)
#       start_indices=(289, 0)
#       strides=(1, 1)
#     ] p
#     wx:u32[2] = squeeze[dimensions=(0,)] ww
#     wy:u32[1,2] = slice[
#       limit_indices=(291, 2)
#       start_indices=(290, 0)
#       strides=(1, 1)
#     ] p
#     wz:u32[2] = squeeze[dimensions=(0,)] wy
#     xa:u32[1,2] = slice[
#       limit_indices=(292, 2)
#       start_indices=(291, 0)
#       strides=(1, 1)
#     ] p
#     xb:u32[2] = squeeze[dimensions=(0,)] xa
#     xc:u32[1,2] = slice[
#       limit_indices=(293, 2)
#       start_indices=(292, 0)
#       strides=(1, 1)
#     ] p
#     xd:u32[2] = squeeze[dimensions=(0,)] xc
#     xe:u32[1,2] = slice[
#       limit_indices=(294, 2)
#       start_indices=(293, 0)
#       strides=(1, 1)
#     ] p
#     xf:u32[2] = squeeze[dimensions=(0,)] xe
#     xg:u32[1,2] = slice[
#       limit_indices=(295, 2)
#       start_indices=(294, 0)
#       strides=(1, 1)
#     ] p
#     xh:u32[2] = squeeze[dimensions=(0,)] xg
#     xi:u32[1,2] = slice[
#       limit_indices=(296, 2)
#       start_indices=(295, 0)
#       strides=(1, 1)
#     ] p
#     xj:u32[2] = squeeze[dimensions=(0,)] xi
#     xk:u32[1,2] = slice[
#       limit_indices=(297, 2)
#       start_indices=(296, 0)
#       strides=(1, 1)
#     ] p
#     xl:u32[2] = squeeze[dimensions=(0,)] xk
#     xm:u32[1,2] = slice[
#       limit_indices=(298, 2)
#       start_indices=(297, 0)
#       strides=(1, 1)
#     ] p
#     xn:u32[2] = squeeze[dimensions=(0,)] xm
#     xo:u32[1,2] = slice[
#       limit_indices=(299, 2)
#       start_indices=(298, 0)
#       strides=(1, 1)
#     ] p
#     xp:u32[2] = squeeze[dimensions=(0,)] xo
#     xq:u32[1,2] = slice[
#       limit_indices=(300, 2)
#       start_indices=(299, 0)
#       strides=(1, 1)
#     ] p
#     xr:u32[2] = squeeze[dimensions=(0,)] xq
#     xs:u32[1,2] = slice[
#       limit_indices=(301, 2)
#       start_indices=(300, 0)
#       strides=(1, 1)
#     ] p
#     xt:u32[2] = squeeze[dimensions=(0,)] xs
#     xu:u32[1,2] = slice[
#       limit_indices=(302, 2)
#       start_indices=(301, 0)
#       strides=(1, 1)
#     ] p
#     xv:u32[2] = squeeze[dimensions=(0,)] xu
#     xw:u32[1,2] = slice[
#       limit_indices=(303, 2)
#       start_indices=(302, 0)
#       strides=(1, 1)
#     ] p
#     xx:u32[2] = squeeze[dimensions=(0,)] xw
#     xy:u32[1,2] = slice[
#       limit_indices=(304, 2)
#       start_indices=(303, 0)
#       strides=(1, 1)
#     ] p
#     xz:u32[2] = squeeze[dimensions=(0,)] xy
#     ya:u32[1,2] = slice[
# ...
#    1144                            flatten_lowering_ir_args(args))
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/interpreters/mlir.py:1124, in _lower_jaxpr_to_fun_cached(ctx, fn_name, call_jaxpr, effects)
#    1122     func_op = ctx.cached_call_jaxpr_lowerings[key]
#    1123   except KeyError:
# -> 1124     func_op = lower_jaxpr_to_fun(ctx, fn_name, call_jaxpr, effects)
#    1125     ctx.cached_call_jaxpr_lowerings[key] = func_op
#    1126 else:
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/interpreters/mlir.py:918, in lower_jaxpr_to_fun(ctx, name, jaxpr, effects, create_tokens, public, replace_tokens_with_dummy, replicated_args, arg_shardings, result_shardings, use_sharding_annotations, input_output_aliases, num_output_tokens)
#     915     args.append(arg)
#     916 callee_name_stack = xla.extend_name_stack(ctx.name_stack,
#     917                                           util.wrap_name(name, 'jit'))
# --> 918 out_vals, tokens_out = jaxpr_subcomp(ctx.replace(name_stack=callee_name_stack),
#     919                                      jaxpr.jaxpr, tokens_in, map(ir_constants, jaxpr.consts),
#     920                                      *args)
#     921 outs = []
#     922 if create_tokens:
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/interpreters/mlir.py:1045, in jaxpr_subcomp(ctx, jaxpr, tokens, consts, *args)
#    1041   axis_size_env = {d: read(d)[0]
#    1042                    for a in avals_in if type(a) is core.DShapedArray
#    1043                    for d in a.shape if type(d) is core.Var}
#    1044   rule_ctx = rule_ctx.replace(axis_size_env=axis_size_env)
# -> 1045 ans = rule(rule_ctx, *map(_unwrap_singleton_ir_values, in_nodes),
#    1046            **eqn.params)
#    1047 if effects:
#    1048   # If there were ordered effects in the primitive, there should be output
#    1049   # tokens we need for subsequent ordered effects.
#    1050   tokens_out = rule_ctx.tokens_out
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/interpreters/mlir.py:1108, in lower_fun.<locals>.f_lowered(ctx, *args, **params)
#    1105   jaxpr, _, consts = pe.trace_to_jaxpr_dynamic(wrapped_fun, ctx.avals_in)
#    1106   # TODO(frostig,mattjj): check ctx.avals_out against jaxpr avals out?
# -> 1108 out, tokens = jaxpr_subcomp(
#    1109     ctx.module_context, jaxpr, ctx.tokens_in, _ir_consts(consts),
#    1110     *map(wrap_singleton_ir_values, args))
#    1111 ctx.set_tokens_out(tokens)
#    1112 return out
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/interpreters/mlir.py:1045, in jaxpr_subcomp(ctx, jaxpr, tokens, consts, *args)
#    1041   axis_size_env = {d: read(d)[0]
#    1042                    for a in avals_in if type(a) is core.DShapedArray
#    1043                    for d in a.shape if type(d) is core.Var}
#    1044   rule_ctx = rule_ctx.replace(axis_size_env=axis_size_env)
# -> 1045 ans = rule(rule_ctx, *map(_unwrap_singleton_ir_values, in_nodes),
#    1046            **eqn.params)
#    1047 if effects:
#    1048   # If there were ordered effects in the primitive, there should be output
#    1049   # tokens we need for subsequent ordered effects.
#    1050   tokens_out = rule_ctx.tokens_out
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:1517, in _while_lowering(ctx, cond_jaxpr, body_jaxpr, cond_nconsts, body_nconsts, *args)
#    1514 x, y, z = util.split_list(body_args, [cond_nconsts, body_nconsts])
#    1515 body_ctx = ctx.module_context.replace(
#    1516     name_stack=xla.extend_name_stack(name_stack, 'body'))
# -> 1517 new_z, tokens_out = mlir.jaxpr_subcomp(body_ctx, body_jaxpr.jaxpr,
#    1518     tokens_in, _map(mlir.ir_constants, body_jaxpr.consts), *(y + z))
#    1519 out_tokens = [tokens_out.get(eff) for eff in body_effects]
#    1520 if batched:
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/interpreters/mlir.py:1045, in jaxpr_subcomp(ctx, jaxpr, tokens, consts, *args)
#    1041   axis_size_env = {d: read(d)[0]
#    1042                    for a in avals_in if type(a) is core.DShapedArray
#    1043                    for d in a.shape if type(d) is core.Var}
#    1044   rule_ctx = rule_ctx.replace(axis_size_env=axis_size_env)
# -> 1045 ans = rule(rule_ctx, *map(_unwrap_singleton_ir_values, in_nodes),
#    1046            **eqn.params)
#    1047 if effects:
#    1048   # If there were ordered effects in the primitive, there should be output
#    1049   # tokens we need for subsequent ordered effects.
#    1050   tokens_out = rule_ctx.tokens_out
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/_src/prng.py:700, in random_bits_lowering(ctx, keys, bit_width, shape)
#     698 bits_lowering = mlir.lower_fun(bits, multiple_results=False)
#     699 ctx_new = ctx.replace(avals_in=[keys_aval_to_base_arr_aval(aval)])
# --> 700 out = bits_lowering(ctx_new, keys)
#     701 ctx.set_tokens_out(ctx_new.tokens_out)
#     702 return out
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/interpreters/mlir.py:1105, in lower_fun.<locals>.f_lowered(ctx, *args, **params)
#    1103   jaxpr, _, consts = pe.trace_to_jaxpr_dynamic2(wrapped_fun)
#    1104 else:
# -> 1105   jaxpr, _, consts = pe.trace_to_jaxpr_dynamic(wrapped_fun, ctx.avals_in)
#    1106   # TODO(frostig,mattjj): check ctx.avals_out against jaxpr avals out?
#    1108 out, tokens = jaxpr_subcomp(
#    1109     ctx.module_context, jaxpr, ctx.tokens_in, _ir_consts(consts),
#    1110     *map(wrap_singleton_ir_values, args))
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/_src/profiler.py:313, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     310 @wraps(func)
#     311 def wrapper(*args, **kwargs):
#     312   with TraceAnnotation(name, **decorator_kwargs):
# --> 313     return func(*args, **kwargs)
#     314   return wrapper
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/interpreters/partial_eval.py:1929, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    1927 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore
#    1928   main.jaxpr_stack = ()  # type: ignore
# -> 1929   jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    1930     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    1931   del main, fun
#    1932 return jaxpr, out_avals, consts
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/interpreters/partial_eval.py:1946, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    1944 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    1945 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 1946 ans = fun.call_wrapped(*in_tracers_)
#    1947 out_tracers = map(trace.full_raise, ans)
#    1948 jaxpr, consts = frame.to_jaxpr(out_tracers)
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/linear_util.py:168, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     165 gen = gen_static_args = out_store = None
#     167 try:
# --> 168   ans = self.f(*args, **dict(self.params, **kwargs))
#     169 except:
#     170   # Some transformations yield from inside context managers, so we have to
#     171   # interrupt them before reraising the exception. Otherwise they will only
#     172   # get garbage-collected at some later time, running their cleanup tasks
#     173   # only after this exception is handled, which can corrupt the global
#     174   # state.
#     175   while stack:
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/interpreters/mlir.py:1086, in lower_fun.<locals>.f_lowered.<locals>.<lambda>(*args, **kw)
#    1085 def f_lowered(ctx, *args, **params):
# -> 1086   f = fun if multiple_results else lambda *args, **kw: (fun(*args, **kw),)
#    1087   wrapped_fun = lu.wrap_init(f, params)
#    1089   if config.jax_dynamic_shapes:
#    1090     # We might be applying this function to arguments with dynamic shapes,
#    1091     # i.e. there might be Vars in the shape tuples of ctx.avals_in. In that
#    1092     # case, we need to form a jaxpr with leading binders for those axis size
#    1093     # arguments (by computing an InputType and using trace_to_jaxpr_dynamic2),
#    1094     # and we need to call jaxpr_subcomp with these arguments made explicit.
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/_src/prng.py:697, in random_bits_lowering.<locals>.<lambda>(k)
#     694 aval, = ctx.avals_in
#     695 impl = aval.dtype.impl
#     696 bits = iterated_vmap_unary(
# --> 697     aval.ndim, lambda k: impl.random_bits(k, bit_width, shape))
#     698 bits_lowering = mlir.lower_fun(bits, multiple_results=False)
#     699 ctx_new = ctx.replace(avals_in=[keys_aval_to_base_arr_aval(aval)])
#
#     [... skipping hidden 1 frame]
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/_src/api.py:528, in _cpp_jit.<locals>.cache_miss(*args, **kwargs)
#     526   in_type = pe.infer_lambda_input_type(None, args_flat)
#     527   flat_fun = lu.annotate(flat_fun, in_type)
# --> 528 out_flat = xla.xla_call(
#     529     flat_fun, *args_flat,
#     530     device=device, backend=backend, name=flat_fun.__name__,
#     531     donated_invars=donated_invars, inline=inline, keep_unused=keep_unused)
#     532 out_pytree_def = out_tree()
#     533 out = tree_unflatten(out_pytree_def, out_flat)
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/core.py:1963, in CallPrimitive.bind(self, fun, *args, **params)
#    1962 def bind(self, fun, *args, **params):
# -> 1963   return call_bind(self, fun, *args, **params)
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/core.py:1979, in call_bind(primitive, fun, *args, **params)
#    1977 tracers = map(top_trace.full_raise, args)
#    1978 fun_ = lu.annotate(fun_, fun.in_type)
# -> 1979 outs = top_trace.process_call(primitive, fun_, tracers, params)
#    1980 return map(full_lower, apply_todos(env_trace_todo(), outs))
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/interpreters/partial_eval.py:1684, in DynamicJaxprTrace.process_call(self, call_primitive, f, explicit_tracers, params)
#    1680 if config.jax_check_tracer_leaks or not config.jax_experimental_subjaxpr_lowering_cache:
#    1681   # TODO(lenamartens): Make call_primitive name -> API function name mapping.
#    1682   # (currently this will display eg. 'xla_call' instead of `jit`)
#    1683   dbg = debug_info_final(f, call_primitive.name)
# -> 1684   jaxpr, out_type, consts = trace_to_subjaxpr_dynamic2(f, self.main, debug_info=dbg)
#    1685 else:
#    1686   jaxpr, out_type, consts = trace_to_subjaxpr_dynamic2_memoized(
#    1687       f, self.main, call_primitive.name).val
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/interpreters/partial_eval.py:1975, in trace_to_subjaxpr_dynamic2(fun, main, debug_info)
#    1973 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    1974 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 1975 ans = fun.call_wrapped(*in_tracers_)
#    1976 out_tracers = map(trace.full_raise, ans)
#    1977 jaxpr, out_type, consts = frame.to_jaxpr2(out_tracers)
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/linear_util.py:168, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     165 gen = gen_static_args = out_store = None
#     167 try:
# --> 168   ans = self.f(*args, **dict(self.params, **kwargs))
#     169 except:
#     170   # Some transformations yield from inside context managers, so we have to
#     171   # interrupt them before reraising the exception. Otherwise they will only
#     172   # get garbage-collected at some later time, running their cleanup tasks
#     173   # only after this exception is handled, which can corrupt the global
#     174   # state.
#     175   while stack:
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/_src/prng.py:1032, in threefry_random_bits(key, bit_width, shape)
#    1029   nblocks, rem = 0, max_count
#    1031 if not nblocks:
# -> 1032   bits = threefry_2x32(key, lax.iota(np.uint32, rem))
#    1033 else:
#    1034   keys = threefry_split(key, nblocks + 1)
#
#     [... skipping hidden 1 frame]
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/_src/api.py:528, in _cpp_jit.<locals>.cache_miss(*args, **kwargs)
#     526   in_type = pe.infer_lambda_input_type(None, args_flat)
#     527   flat_fun = lu.annotate(flat_fun, in_type)
# --> 528 out_flat = xla.xla_call(
#     529     flat_fun, *args_flat,
#     530     device=device, backend=backend, name=flat_fun.__name__,
#     531     donated_invars=donated_invars, inline=inline, keep_unused=keep_unused)
#     532 out_pytree_def = out_tree()
#     533 out = tree_unflatten(out_pytree_def, out_flat)
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/core.py:1963, in CallPrimitive.bind(self, fun, *args, **params)
#    1962 def bind(self, fun, *args, **params):
# -> 1963   return call_bind(self, fun, *args, **params)
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/core.py:1979, in call_bind(primitive, fun, *args, **params)
#    1977 tracers = map(top_trace.full_raise, args)
#    1978 fun_ = lu.annotate(fun_, fun.in_type)
# -> 1979 outs = top_trace.process_call(primitive, fun_, tracers, params)
#    1980 return map(full_lower, apply_todos(env_trace_todo(), outs))
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/interpreters/partial_eval.py:1684, in DynamicJaxprTrace.process_call(self, call_primitive, f, explicit_tracers, params)
#    1680 if config.jax_check_tracer_leaks or not config.jax_experimental_subjaxpr_lowering_cache:
#    1681   # TODO(lenamartens): Make call_primitive name -> API function name mapping.
#    1682   # (currently this will display eg. 'xla_call' instead of `jit`)
#    1683   dbg = debug_info_final(f, call_primitive.name)
# -> 1684   jaxpr, out_type, consts = trace_to_subjaxpr_dynamic2(f, self.main, debug_info=dbg)
#    1685 else:
#    1686   jaxpr, out_type, consts = trace_to_subjaxpr_dynamic2_memoized(
#    1687       f, self.main, call_primitive.name).val
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/interpreters/partial_eval.py:1977, in trace_to_subjaxpr_dynamic2(fun, main, debug_info)
#    1975   ans = fun.call_wrapped(*in_tracers_)
#    1976   out_tracers = map(trace.full_raise, ans)
# -> 1977   jaxpr, out_type, consts = frame.to_jaxpr2(out_tracers)
#    1978   del fun, main, trace, frame, in_tracers, out_tracers, ans
#    1979 return jaxpr, out_type, consts
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/interpreters/partial_eval.py:1484, in JaxprStackFrame.to_jaxpr2(self, out_tracers)
#    1482 # We can't run check_jaxpr until after we normalize.
#    1483 jaxpr, constvals = _const_folding_and_forwarding(jaxpr, constvals)
# -> 1484 jaxpr, constvals = _inline_literals(jaxpr, constvals)
#    1485 jaxpr, out_type = _add_implicit_outputs(jaxpr)
#    1486 config.jax_enable_checks and core.check_jaxpr(jaxpr)
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/interpreters/partial_eval.py:1578, in _inline_literals(jaxpr, constvals)
#    1576   invars = [lit(v) or var(v) for v in eqn.invars]
#    1577   outvars = [var(v) if v in used else dropvar(v.aval) for v in eqn.outvars]
# -> 1578   new_eqns.append(eqn.replace(invars=invars, outvars=outvars))
#    1579 new_outvars = [lit(v) or var(v) for v in jaxpr.outvars]
#    1580 new_jaxpr = Jaxpr(new_constvars, new_invars, new_outvars, new_eqns,
#    1581                   jaxpr.effects)
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/site-packages/jax/core.py:209, in JaxprEqn.replace(self, *args, **kwargs)
#     208 def replace(self, *args, **kwargs):
# --> 209   return self._replace(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/pfjax2/lib/python3.9/collections/__init__.py:447, in namedtuple.<locals>._replace(self, **kwds)
#     442     return result
#     444 _make.__func__.__doc__ = (f'Make a new {typename} object from a sequence '
#     445                           'or iterable')
# --> 447 def _replace(self, /, **kwds):
#     448     result = self._make(_map(kwds.pop, field_names, self))
#     449     if kwds:
#
# KeyboardInterrupt:

# %%
num_warmup = 2000

posteriors = pd.DataFrame(
    pg_out["theta"][num_warmup:], 
    columns = ["theta", "kappa", "sigma_z", "mu"])

plot_posteriors = pd.melt(posteriors, var_name = "param")

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 6), sharex = True)
sns.lineplot(pg_out["theta"][:, 0], ax = ax[0,0], label="_theta")
sns.lineplot(pg_out["theta"][:, 1], ax = ax[0,1], label="kappa")
sns.lineplot(pg_out["theta"][:, 2], ax = ax[1,0], label="sigma_z")
sns.lineplot(pg_out["theta"][:, 3], ax = ax[1,1], label="mu");

# %%
g = sns.FacetGrid(plot_posteriors,
                  sharex=False, sharey=1,
                  col="param", height=3, aspect=1.3, col_wrap=2)
g.map(sns.histplot, "value")
[g.axes[i].axvline(x=theta[i], color = "firebrick", ls='--') for i in range(len(theta))];
